# %%
import numpy as np
import matplotlib.pyplot as plt
import auxiliary as aux
from copy import copy
import Thompson_Sampling as TS
import Particle_Thompson_Sampling as PTS
import Particle_Regeneration as PR
import RBMLE
import pickle


np.set_printoptions(precision=4)


def run_simulations(K, T, Npar, N_simul, alg):
    
    x = np.zeros(T)
    y = np.zeros(T)
    for i in range(N_simul):
        if i % 1 == 0:
            print(str(K)+'-Arm, ' + alg + ', Npar=' + str(Npar) + ' Simulation ', i)
        
        if alg == 'TS':
            G = TS.System_TS(K,T)
            G.init_true_parameter()
            G.find_best_action()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = []
            
        if alg == 'RBMLE':
            G = RBMLE.System_RBMLE(K,T)
            G.init_true_parameter()
            G.find_best_action()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG 
            z = []
        
        if alg == 'PTS':
            G = PTS.System_PTS(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = []
        
        if alg == 'PR1':
            G = PR.System_PR1(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = []

        if alg == 'PR2':
            G = PR.System_PR2(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = []

        if alg == 'PR3':
            G = PR.System_PR3(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = []

        if alg == 'PR4':
            G = PR.System_PR4(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = G.epochs

        if alg == 'PR5':
            G = PR.System_PR5(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = G.epochs
            
        if alg == 'PR6':
            G = PR.System_PR6(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG  
            z = G.epochs

        if alg == 'PR7':
            G = PR.System_PR7(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = G.epochs

        if alg == 'PR7a':
            G = PR.System_PR7a(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = G.epochs


        if alg == 'PR8':
            G = PR.System_PR8(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = G.epochs

        if alg == 'PR9':
            G = PR.System_PR9(K,T,Npar)
            G.init_true_parameter()
            G.find_best_action()
            G.init_particles()
            G.run()
            x += G.CUM_REG
            y += G.AVG_REG
            z = G.epochs

    #print('theta_true =', G.theta_true)  
    
    x = x / N_simul
    y = y / N_simul
    z = z
    return (x, y, z)

# %%
## Set up model parameters
K = 2       # number of arms
T = 200000      # time horizon
Npar = 100    # number of particles
#T_epoch = 4  # Epoch time 
N_simul = 500   # number of simulations
    
alg = 'PR7'
Npar= 100
(x,y,z) = run_simulations(K,T,Npar,N_simul,alg)
#fw = open('data/Bernoulli' + str(K) + '/Bernoulli' + str(K) + '_' + alg + '_N' + str(Npar) + '_CUM', 'wb')
#fw = open('data/Bernoulli' + str(K) + '/Bernoulli' + str(K) + '_' + 'theta_0.61_to_0.70_' + alg + '_N' + str(Npar) + '_CUM', 'wb')
fw = open('data/Bernoulli' + str(K) + '/Bernoulli' + str(K) + '_' + 'theta_0.6_0.7_' + alg + '_N' + str(Npar) + '_T200K_CUM', 'wb')
pickle.dump(x, fw)
fw.close()
#fw = open('data/Bernoulli' + str(K) + '/Bernoulli' + str(K) + '_' + alg + '_N' + str(Npar) + '_AVG', 'wb')
#fw = open('data/Bernoulli' + str(K) + '/Bernoulli' + str(K) + '_' + 'theta_0.61_to_0.70_' + alg + '_N' + str(Npar) + '_AVG', 'wb')
fw = open('data/Bernoulli' + str(K) + '/Bernoulli' + str(K) + '_' + 'theta_0.6_0.7_' + alg + '_N' + str(Npar) + '_T200K_AVG', 'wb')
pickle.dump(y, fw)
fw.close()
# Out:
# 2-Arm, PTS, Npar=100 Simulation  0
# 2-Arm, PTS, Npar=100 Simulation  1
# 2-Arm, PTS, Npar=100 Simulation  2
# 2-Arm, PTS, Npar=100 Simulation  3
# 2-Arm, PTS, Npar=100 Simulation  4
# 2-Arm, PTS, Npar=100 Simulation  5
# 2-Arm, PTS, Npar=100 Simulation  6
# 2-Arm, PTS, Npar=100 Simulation  7
# 2-Arm, PTS, Npar=100 Simulation  8
# 2-Arm, PTS, Npar=100 Simulation  9
# 2-Arm, PTS, Npar=100 Simulation  10
# 2-Arm, PTS, Npar=100 Simulation  11
# 2-Arm, PTS, Npar=100 Simulation  12
# 2-Arm, PTS, Npar=100 Simulation  13
# 2-Arm, PTS, Npar=100 Simulation  14
# 2-Arm, PTS, Npar=100 Simulation  15
# 2-Arm, PTS, Npar=100 Simulation  16
# 2-Arm, PTS, Npar=100 Simulation  17
# 2-Arm, PTS, Npar=100 Simulation  18
# 2-Arm, PTS, Npar=100 Simulation  19
# 2-Arm, PTS, Npar=100 Simulation  20
# 2-Arm, PTS, Npar=100 Simulation  21
# 2-Arm, PTS, Npar=100 Simulation  22
# 2-Arm, PTS, Npar=100 Simulation  23
# 2-Arm, PTS, Npar=100 Simulation  24
# 2-Arm, PTS, Npar=100 Simulation  25
# 2-Arm, PTS, Npar=100 Simulation  26
# 2-Arm, PTS, Npar=100 Simulation  27
# 2-Arm, PTS, Npar=100 Simulation  28
# 2-Arm, PTS, Npar=100 Simulation  29
# 2-Arm, PTS, Npar=100 Simulation  30
# 2-Arm, PTS, Npar=100 Simulation  31
# 2-Arm, PTS, Npar=100 Simulation  32
# 2-Arm, PTS, Npar=100 Simulation  33
# 2-Arm, PTS, Npar=100 Simulation  34
# 2-Arm, PTS, Npar=100 Simulation  35
# 2-Arm, PTS, Npar=100 Simulation  36
# 2-Arm, PTS, Npar=100 Simulation  37
# 2-Arm, PTS, Npar=100 Simulation  38
# 2-Arm, PTS, Npar=100 Simulation  39
# 2-Arm, PTS, Npar=100 Simulation  40
# 2-Arm, PTS, Npar=100 Simulation  41
# 2-Arm, PTS, Npar=100 Simulation  42
# 2-Arm, PTS, Npar=100 Simulation  43
# 2-Arm, PTS, Npar=100 Simulation  44
# 2-Arm, PTS, Npar=100 Simulation  45
# 2-Arm, PTS, Npar=100 Simulation  46
# 2-Arm, PTS, Npar=100 Simulation  47
# 2-Arm, PTS, Npar=100 Simulation  48
# 2-Arm, PTS, Npar=100 Simulation  49
# 2-Arm, PTS, Npar=100 Simulation  50
# 2-Arm, PTS, Npar=100 Simulation  51
# 2-Arm, PTS, Npar=100 Simulation  52
# 2-Arm, PTS, Npar=100 Simulation  53
# 2-Arm, PTS, Npar=100 Simulation  54
# 2-Arm, PTS, Npar=100 Simulation  55
# 2-Arm, PTS, Npar=100 Simulation  56
# 2-Arm, PTS, Npar=100 Simulation  57
# 2-Arm, PTS, Npar=100 Simulation  58
# 2-Arm, PTS, Npar=100 Simulation  59
# 2-Arm, PTS, Npar=100 Simulation  60
# 2-Arm, PTS, Npar=100 Simulation  61
# 2-Arm, PTS, Npar=100 Simulation  62
# 2-Arm, PTS, Npar=100 Simulation  63
# 2-Arm, PTS, Npar=100 Simulation  64
# 2-Arm, PTS, Npar=100 Simulation  65
# 2-Arm, PTS, Npar=100 Simulation  66
# 2-Arm, PTS, Npar=100 Simulation  67
# 2-Arm, PTS, Npar=100 Simulation  68
# 2-Arm, PTS, Npar=100 Simulation  69
# 2-Arm, PTS, Npar=100 Simulation  70
# 2-Arm, PTS, Npar=100 Simulation  71
# 2-Arm, PTS, Npar=100 Simulation  72
# 2-Arm, PTS, Npar=100 Simulation  73
# 2-Arm, PTS, Npar=100 Simulation  74
# 2-Arm, PTS, Npar=100 Simulation  75
# 2-Arm, PTS, Npar=100 Simulation  76
# 2-Arm, PTS, Npar=100 Simulation  77
# 2-Arm, PTS, Npar=100 Simulation  78
# 2-Arm, PTS, Npar=100 Simulation  79
# 2-Arm, PTS, Npar=100 Simulation  80
# 2-Arm, PTS, Npar=100 Simulation  81
# 2-Arm, PTS, Npar=100 Simulation  82
# 2-Arm, PTS, Npar=100 Simulation  83
# 2-Arm, PTS, Npar=100 Simulation  84
# 2-Arm, PTS, Npar=100 Simulation  85
# 2-Arm, PTS, Npar=100 Simulation  86
# 2-Arm, PTS, Npar=100 Simulation  87
# 2-Arm, PTS, Npar=100 Simulation  88
# 2-Arm, PTS, Npar=100 Simulation  89
# 2-Arm, PTS, Npar=100 Simulation  90
# 2-Arm, PTS, Npar=100 Simulation  91
# 2-Arm, PTS, Npar=100 Simulation  92
# 2-Arm, PTS, Npar=100 Simulation  93
# 2-Arm, PTS, Npar=100 Simulation  94
# 2-Arm, PTS, Npar=100 Simulation  95
# 2-Arm, PTS, Npar=100 Simulation  96
# 2-Arm, PTS, Npar=100 Simulation  97
# 2-Arm, PTS, Npar=100 Simulation  98
# 2-Arm, PTS, Npar=100 Simulation  99
# 2-Arm, PTS, Npar=100 Simulation  100
# 2-Arm, PTS, Npar=100 Simulation  101
# 2-Arm, PTS, Npar=100 Simulation  102
# 2-Arm, PTS, Npar=100 Simulation  103
# 2-Arm, PTS, Npar=100 Simulation  104
# 2-Arm, PTS, Npar=100 Simulation  105
# 2-Arm, PTS, Npar=100 Simulation  106
# 2-Arm, PTS, Npar=100 Simulation  107
# 2-Arm, PTS, Npar=100 Simulation  108
# 2-Arm, PTS, Npar=100 Simulation  109
# 2-Arm, PTS, Npar=100 Simulation  110
# 2-Arm, PTS, Npar=100 Simulation  111
# 2-Arm, PTS, Npar=100 Simulation  112
# 2-Arm, PTS, Npar=100 Simulation  113
# 2-Arm, PTS, Npar=100 Simulation  114
# 2-Arm, PTS, Npar=100 Simulation  115
# 2-Arm, PTS, Npar=100 Simulation  116
# 2-Arm, PTS, Npar=100 Simulation  117
# 2-Arm, PTS, Npar=100 Simulation  118
# 2-Arm, PTS, Npar=100 Simulation  119
# 2-Arm, PTS, Npar=100 Simulation  120
# 2-Arm, PTS, Npar=100 Simulation  121
# 2-Arm, PTS, Npar=100 Simulation  122
# 2-Arm, PTS, Npar=100 Simulation  123
# 2-Arm, PTS, Npar=100 Simulation  124
# 2-Arm, PTS, Npar=100 Simulation  125
# 2-Arm, PTS, Npar=100 Simulation  126
# 2-Arm, PTS, Npar=100 Simulation  127
# 2-Arm, PTS, Npar=100 Simulation  128
# 2-Arm, PTS, Npar=100 Simulation  129
# 2-Arm, PTS, Npar=100 Simulation  130
# 2-Arm, PTS, Npar=100 Simulation  131
# 2-Arm, PTS, Npar=100 Simulation  132
# 2-Arm, PTS, Npar=100 Simulation  133
# 2-Arm, PTS, Npar=100 Simulation  134
# 2-Arm, PTS, Npar=100 Simulation  135
# 2-Arm, PTS, Npar=100 Simulation  136
# 2-Arm, PTS, Npar=100 Simulation  137
# 2-Arm, PTS, Npar=100 Simulation  138
# 2-Arm, PTS, Npar=100 Simulation  139
# 2-Arm, PTS, Npar=100 Simulation  140
# 2-Arm, PTS, Npar=100 Simulation  141
# 2-Arm, PTS, Npar=100 Simulation  142
# 2-Arm, PTS, Npar=100 Simulation  143
# 2-Arm, PTS, Npar=100 Simulation  144
# 2-Arm, PTS, Npar=100 Simulation  145
# 2-Arm, PTS, Npar=100 Simulation  146
# 2-Arm, PTS, Npar=100 Simulation  147
# 2-Arm, PTS, Npar=100 Simulation  148
# 2-Arm, PTS, Npar=100 Simulation  149
# 2-Arm, PTS, Npar=100 Simulation  150
# 2-Arm, PTS, Npar=100 Simulation  151
# 2-Arm, PTS, Npar=100 Simulation  152
# 2-Arm, PTS, Npar=100 Simulation  153
# 2-Arm, PTS, Npar=100 Simulation  154
# 2-Arm, PTS, Npar=100 Simulation  155
# 2-Arm, PTS, Npar=100 Simulation  156
# 2-Arm, PTS, Npar=100 Simulation  157
# 2-Arm, PTS, Npar=100 Simulation  158
# 2-Arm, PTS, Npar=100 Simulation  159
# 2-Arm, PTS, Npar=100 Simulation  160
# 2-Arm, PTS, Npar=100 Simulation  161
# 2-Arm, PTS, Npar=100 Simulation  162
# 2-Arm, PTS, Npar=100 Simulation  163
# 2-Arm, PTS, Npar=100 Simulation  164
# 2-Arm, PTS, Npar=100 Simulation  165
# 2-Arm, PTS, Npar=100 Simulation  166
# 2-Arm, PTS, Npar=100 Simulation  167
# 2-Arm, PTS, Npar=100 Simulation  168
# 2-Arm, PTS, Npar=100 Simulation  169
# 2-Arm, PTS, Npar=100 Simulation  170
# 2-Arm, PTS, Npar=100 Simulation  171
# 2-Arm, PTS, Npar=100 Simulation  172
# 2-Arm, PTS, Npar=100 Simulation  173
# 2-Arm, PTS, Npar=100 Simulation  174
# 2-Arm, PTS, Npar=100 Simulation  175
# 2-Arm, PTS, Npar=100 Simulation  176
# 2-Arm, PTS, Npar=100 Simulation  177
# 2-Arm, PTS, Npar=100 Simulation  178
# 2-Arm, PTS, Npar=100 Simulation  179
# 2-Arm, PTS, Npar=100 Simulation  180
# 2-Arm, PTS, Npar=100 Simulation  181
# 2-Arm, PTS, Npar=100 Simulation  182
# 2-Arm, PTS, Npar=100 Simulation  183
# 2-Arm, PTS, Npar=100 Simulation  184
# 2-Arm, PTS, Npar=100 Simulation  185
# 2-Arm, PTS, Npar=100 Simulation  186
# 2-Arm, PTS, Npar=100 Simulation  187
# 2-Arm, PTS, Npar=100 Simulation  188
# 2-Arm, PTS, Npar=100 Simulation  189
# 2-Arm, PTS, Npar=100 Simulation  190
# 2-Arm, PTS, Npar=100 Simulation  191
# 2-Arm, PTS, Npar=100 Simulation  192
# 2-Arm, PTS, Npar=100 Simulation  193
# 2-Arm, PTS, Npar=100 Simulation  194
# 2-Arm, PTS, Npar=100 Simulation  195
# 2-Arm, PTS, Npar=100 Simulation  196
# 2-Arm, PTS, Npar=100 Simulation  197
# 2-Arm, PTS, Npar=100 Simulation  198
# 2-Arm, PTS, Npar=100 Simulation  199
# 2-Arm, PTS, Npar=100 Simulation  200
# 2-Arm, PTS, Npar=100 Simulation  201
# 2-Arm, PTS, Npar=100 Simulation  202
# 2-Arm, PTS, Npar=100 Simulation  203
# 2-Arm, PTS, Npar=100 Simulation  204
# 2-Arm, PTS, Npar=100 Simulation  205
# 2-Arm, PTS, Npar=100 Simulation  206
# 2-Arm, PTS, Npar=100 Simulation  207
# 2-Arm, PTS, Npar=100 Simulation  208
# 2-Arm, PTS, Npar=100 Simulation  209
# 2-Arm, PTS, Npar=100 Simulation  210
# 2-Arm, PTS, Npar=100 Simulation  211
# 2-Arm, PTS, Npar=100 Simulation  212
# 2-Arm, PTS, Npar=100 Simulation  213
# 2-Arm, PTS, Npar=100 Simulation  214
# 2-Arm, PTS, Npar=100 Simulation  215
# 2-Arm, PTS, Npar=100 Simulation  216
# 2-Arm, PTS, Npar=100 Simulation  217
# 2-Arm, PTS, Npar=100 Simulation  218
# 2-Arm, PTS, Npar=100 Simulation  219
# 2-Arm, PTS, Npar=100 Simulation  220
# 2-Arm, PTS, Npar=100 Simulation  221
# 2-Arm, PTS, Npar=100 Simulation  222
# 2-Arm, PTS, Npar=100 Simulation  223
# 2-Arm, PTS, Npar=100 Simulation  224
# 2-Arm, PTS, Npar=100 Simulation  225
# 2-Arm, PTS, Npar=100 Simulation  226
# 2-Arm, PTS, Npar=100 Simulation  227
# 2-Arm, PTS, Npar=100 Simulation  228
# 2-Arm, PTS, Npar=100 Simulation  229
# 2-Arm, PTS, Npar=100 Simulation  230
# 2-Arm, PTS, Npar=100 Simulation  231
# 2-Arm, PTS, Npar=100 Simulation  232
# 2-Arm, PTS, Npar=100 Simulation  233
# 2-Arm, PTS, Npar=100 Simulation  234
# 2-Arm, PTS, Npar=100 Simulation  235
# 2-Arm, PTS, Npar=100 Simulation  236
# 2-Arm, PTS, Npar=100 Simulation  237
# 2-Arm, PTS, Npar=100 Simulation  238
# 2-Arm, PTS, Npar=100 Simulation  239
# 2-Arm, PTS, Npar=100 Simulation  240
# 2-Arm, PTS, Npar=100 Simulation  241
# 2-Arm, PTS, Npar=100 Simulation  242
# 2-Arm, PTS, Npar=100 Simulation  243
# 2-Arm, PTS, Npar=100 Simulation  244
# 2-Arm, PTS, Npar=100 Simulation  245
# 2-Arm, PTS, Npar=100 Simulation  246
# 2-Arm, PTS, Npar=100 Simulation  247
# 2-Arm, PTS, Npar=100 Simulation  248
# 2-Arm, PTS, Npar=100 Simulation  249
# 2-Arm, PTS, Npar=100 Simulation  250
# 2-Arm, PTS, Npar=100 Simulation  251
# 2-Arm, PTS, Npar=100 Simulation  252
# 2-Arm, PTS, Npar=100 Simulation  253
# 2-Arm, PTS, Npar=100 Simulation  254
# 2-Arm, PTS, Npar=100 Simulation  255
# 2-Arm, PTS, Npar=100 Simulation  256
# 2-Arm, PTS, Npar=100 Simulation  257
# 2-Arm, PTS, Npar=100 Simulation  258
# 2-Arm, PTS, Npar=100 Simulation  259
# 2-Arm, PTS, Npar=100 Simulation  260
# 2-Arm, PTS, Npar=100 Simulation  261
# 2-Arm, PTS, Npar=100 Simulation  262
# 2-Arm, PTS, Npar=100 Simulation  263
# 2-Arm, PTS, Npar=100 Simulation  264
# 2-Arm, PTS, Npar=100 Simulation  265
# 2-Arm, PTS, Npar=100 Simulation  266
# 2-Arm, PTS, Npar=100 Simulation  267
# 2-Arm, PTS, Npar=100 Simulation  268
# 2-Arm, PTS, Npar=100 Simulation  269
# 2-Arm, PTS, Npar=100 Simulation  270
# 2-Arm, PTS, Npar=100 Simulation  271
# 2-Arm, PTS, Npar=100 Simulation  272
# 2-Arm, PTS, Npar=100 Simulation  273
# 2-Arm, PTS, Npar=100 Simulation  274
# 2-Arm, PTS, Npar=100 Simulation  275
# 2-Arm, PTS, Npar=100 Simulation  276
# 2-Arm, PTS, Npar=100 Simulation  277
# 2-Arm, PTS, Npar=100 Simulation  278
# 2-Arm, PTS, Npar=100 Simulation  279
# 2-Arm, PTS, Npar=100 Simulation  280
# 2-Arm, PTS, Npar=100 Simulation  281
# 2-Arm, PTS, Npar=100 Simulation  282
# 2-Arm, PTS, Npar=100 Simulation  283
# 2-Arm, PTS, Npar=100 Simulation  284
# 2-Arm, PTS, Npar=100 Simulation  285
# 2-Arm, PTS, Npar=100 Simulation  286
# 2-Arm, PTS, Npar=100 Simulation  287
# 2-Arm, PTS, Npar=100 Simulation  288
# 2-Arm, PTS, Npar=100 Simulation  289
# 2-Arm, PTS, Npar=100 Simulation  290
# 2-Arm, PTS, Npar=100 Simulation  291
# 2-Arm, PTS, Npar=100 Simulation  292
# 2-Arm, PTS, Npar=100 Simulation  293
# 2-Arm, PTS, Npar=100 Simulation  294
# 2-Arm, PTS, Npar=100 Simulation  295
# 2-Arm, PTS, Npar=100 Simulation  296
# 2-Arm, PTS, Npar=100 Simulation  297
# 2-Arm, PTS, Npar=100 Simulation  298
# 2-Arm, PTS, Npar=100 Simulation  299
# 2-Arm, PTS, Npar=100 Simulation  300
# 2-Arm, PTS, Npar=100 Simulation  301
# 2-Arm, PTS, Npar=100 Simulation  302
# 2-Arm, PTS, Npar=100 Simulation  303
# 2-Arm, PTS, Npar=100 Simulation  304
# 2-Arm, PTS, Npar=100 Simulation  305
# 2-Arm, PTS, Npar=100 Simulation  306
# 2-Arm, PTS, Npar=100 Simulation  307
# 2-Arm, PTS, Npar=100 Simulation  308
# 2-Arm, PTS, Npar=100 Simulation  309
# 2-Arm, PTS, Npar=100 Simulation  310
# 2-Arm, PTS, Npar=100 Simulation  311
# 2-Arm, PTS, Npar=100 Simulation  312
# 2-Arm, PTS, Npar=100 Simulation  313
# 2-Arm, PTS, Npar=100 Simulation  314
# 2-Arm, PTS, Npar=100 Simulation  315
# 2-Arm, PTS, Npar=100 Simulation  316
# 2-Arm, PTS, Npar=100 Simulation  317
# 2-Arm, PTS, Npar=100 Simulation  318
# 2-Arm, PTS, Npar=100 Simulation  319
# 2-Arm, PTS, Npar=100 Simulation  320
# 2-Arm, PTS, Npar=100 Simulation  321
# 2-Arm, PTS, Npar=100 Simulation  322
# 2-Arm, PTS, Npar=100 Simulation  323
# 2-Arm, PTS, Npar=100 Simulation  324
# 2-Arm, PTS, Npar=100 Simulation  325
# 2-Arm, PTS, Npar=100 Simulation  326
# 2-Arm, PTS, Npar=100 Simulation  327
# 2-Arm, PTS, Npar=100 Simulation  328
# 2-Arm, PTS, Npar=100 Simulation  329
# 2-Arm, PTS, Npar=100 Simulation  330
# 2-Arm, PTS, Npar=100 Simulation  331
# 2-Arm, PTS, Npar=100 Simulation  332
# 2-Arm, PTS, Npar=100 Simulation  333
# 2-Arm, PTS, Npar=100 Simulation  334
# 2-Arm, PTS, Npar=100 Simulation  335
# 2-Arm, PTS, Npar=100 Simulation  336
# 2-Arm, PTS, Npar=100 Simulation  337
# 2-Arm, PTS, Npar=100 Simulation  338
# 2-Arm, PTS, Npar=100 Simulation  339
# 2-Arm, PTS, Npar=100 Simulation  340
# 2-Arm, PTS, Npar=100 Simulation  341
# 2-Arm, PTS, Npar=100 Simulation  342
# 2-Arm, PTS, Npar=100 Simulation  343
# 2-Arm, PTS, Npar=100 Simulation  344
# 2-Arm, PTS, Npar=100 Simulation  345
# 2-Arm, PTS, Npar=100 Simulation  346
# 2-Arm, PTS, Npar=100 Simulation  347
# 2-Arm, PTS, Npar=100 Simulation  348
# 2-Arm, PTS, Npar=100 Simulation  349
# 2-Arm, PTS, Npar=100 Simulation  350
# 2-Arm, PTS, Npar=100 Simulation  351
# 2-Arm, PTS, Npar=100 Simulation  352
# 2-Arm, PTS, Npar=100 Simulation  353
# 2-Arm, PTS, Npar=100 Simulation  354
# 2-Arm, PTS, Npar=100 Simulation  355
# 2-Arm, PTS, Npar=100 Simulation  356
# 2-Arm, PTS, Npar=100 Simulation  357
# 2-Arm, PTS, Npar=100 Simulation  358
# 2-Arm, PTS, Npar=100 Simulation  359
# 2-Arm, PTS, Npar=100 Simulation  360
# 2-Arm, PTS, Npar=100 Simulation  361
# 2-Arm, PTS, Npar=100 Simulation  362
# 2-Arm, PTS, Npar=100 Simulation  363
# 2-Arm, PTS, Npar=100 Simulation  364
# 2-Arm, PTS, Npar=100 Simulation  365
# 2-Arm, PTS, Npar=100 Simulation  366
# 2-Arm, PTS, Npar=100 Simulation  367
# 2-Arm, PTS, Npar=100 Simulation  368
# 2-Arm, PTS, Npar=100 Simulation  369
# 2-Arm, PTS, Npar=100 Simulation  370
# 2-Arm, PTS, Npar=100 Simulation  371
# 2-Arm, PTS, Npar=100 Simulation  372
# 2-Arm, PTS, Npar=100 Simulation  373
# 2-Arm, PTS, Npar=100 Simulation  374
# 2-Arm, PTS, Npar=100 Simulation  375
# 2-Arm, PTS, Npar=100 Simulation  376
# 2-Arm, PTS, Npar=100 Simulation  377
# 2-Arm, PTS, Npar=100 Simulation  378
# 2-Arm, PTS, Npar=100 Simulation  379
# 2-Arm, PTS, Npar=100 Simulation  380
# 2-Arm, PTS, Npar=100 Simulation  381
# 2-Arm, PTS, Npar=100 Simulation  382
# 2-Arm, PTS, Npar=100 Simulation  383
# 2-Arm, PTS, Npar=100 Simulation  384
# 2-Arm, PTS, Npar=100 Simulation  385
# 2-Arm, PTS, Npar=100 Simulation  386
# 2-Arm, PTS, Npar=100 Simulation  387
# 2-Arm, PTS, Npar=100 Simulation  388
# 2-Arm, PTS, Npar=100 Simulation  389
# 2-Arm, PTS, Npar=100 Simulation  390
# 2-Arm, PTS, Npar=100 Simulation  391
# 2-Arm, PTS, Npar=100 Simulation  392
# 2-Arm, PTS, Npar=100 Simulation  393
# 2-Arm, PTS, Npar=100 Simulation  394
# 2-Arm, PTS, Npar=100 Simulation  395
# 2-Arm, PTS, Npar=100 Simulation  396
# 2-Arm, PTS, Npar=100 Simulation  397
# 2-Arm, PTS, Npar=100 Simulation  398
# 2-Arm, PTS, Npar=100 Simulation  399
# 2-Arm, PTS, Npar=100 Simulation  400
# 2-Arm, PTS, Npar=100 Simulation  401
# 2-Arm, PTS, Npar=100 Simulation  402
# 2-Arm, PTS, Npar=100 Simulation  403
# 2-Arm, PTS, Npar=100 Simulation  404
# 2-Arm, PTS, Npar=100 Simulation  405
# 2-Arm, PTS, Npar=100 Simulation  406
# 2-Arm, PTS, Npar=100 Simulation  407
# 2-Arm, PTS, Npar=100 Simulation  408
# 2-Arm, PTS, Npar=100 Simulation  409
# 2-Arm, PTS, Npar=100 Simulation  410
# 2-Arm, PTS, Npar=100 Simulation  411
# 2-Arm, PTS, Npar=100 Simulation  412
# 2-Arm, PTS, Npar=100 Simulation  413
# 2-Arm, PTS, Npar=100 Simulation  414
# 2-Arm, PTS, Npar=100 Simulation  415
# 2-Arm, PTS, Npar=100 Simulation  416
# 2-Arm, PTS, Npar=100 Simulation  417
# 2-Arm, PTS, Npar=100 Simulation  418
# 2-Arm, PTS, Npar=100 Simulation  419
# 2-Arm, PTS, Npar=100 Simulation  420
# 2-Arm, PTS, Npar=100 Simulation  421
# 2-Arm, PTS, Npar=100 Simulation  422
# 2-Arm, PTS, Npar=100 Simulation  423
# 2-Arm, PTS, Npar=100 Simulation  424
# 2-Arm, PTS, Npar=100 Simulation  425
# 2-Arm, PTS, Npar=100 Simulation  426
# 2-Arm, PTS, Npar=100 Simulation  427
# 2-Arm, PTS, Npar=100 Simulation  428
# 2-Arm, PTS, Npar=100 Simulation  429
# 2-Arm, PTS, Npar=100 Simulation  430
# 2-Arm, PTS, Npar=100 Simulation  431
# 2-Arm, PTS, Npar=100 Simulation  432
# 2-Arm, PTS, Npar=100 Simulation  433
# 2-Arm, PTS, Npar=100 Simulation  434
# 2-Arm, PTS, Npar=100 Simulation  435
# 2-Arm, PTS, Npar=100 Simulation  436
# 2-Arm, PTS, Npar=100 Simulation  437
# 2-Arm, PTS, Npar=100 Simulation  438
# 2-Arm, PTS, Npar=100 Simulation  439
# 2-Arm, PTS, Npar=100 Simulation  440
# 2-Arm, PTS, Npar=100 Simulation  441
# 2-Arm, PTS, Npar=100 Simulation  442
# 2-Arm, PTS, Npar=100 Simulation  443
# 2-Arm, PTS, Npar=100 Simulation  444
# 2-Arm, PTS, Npar=100 Simulation  445
# 2-Arm, PTS, Npar=100 Simulation  446
# 2-Arm, PTS, Npar=100 Simulation  447
# 2-Arm, PTS, Npar=100 Simulation  448
# 2-Arm, PTS, Npar=100 Simulation  449
# 2-Arm, PTS, Npar=100 Simulation  450
# 2-Arm, PTS, Npar=100 Simulation  451
# 2-Arm, PTS, Npar=100 Simulation  452
# 2-Arm, PTS, Npar=100 Simulation  453
# 2-Arm, PTS, Npar=100 Simulation  454
# 2-Arm, PTS, Npar=100 Simulation  455
# 2-Arm, PTS, Npar=100 Simulation  456
# 2-Arm, PTS, Npar=100 Simulation  457
# 2-Arm, PTS, Npar=100 Simulation  458
# 2-Arm, PTS, Npar=100 Simulation  459
# 2-Arm, PTS, Npar=100 Simulation  460
# 2-Arm, PTS, Npar=100 Simulation  461
# 2-Arm, PTS, Npar=100 Simulation  462
# 2-Arm, PTS, Npar=100 Simulation  463
# 2-Arm, PTS, Npar=100 Simulation  464
# 2-Arm, PTS, Npar=100 Simulation  465
# 2-Arm, PTS, Npar=100 Simulation  466
# 2-Arm, PTS, Npar=100 Simulation  467
# 2-Arm, PTS, Npar=100 Simulation  468
# 2-Arm, PTS, Npar=100 Simulation  469
# 2-Arm, PTS, Npar=100 Simulation  470
# 2-Arm, PTS, Npar=100 Simulation  471
# 2-Arm, PTS, Npar=100 Simulation  472
# 2-Arm, PTS, Npar=100 Simulation  473
# 2-Arm, PTS, Npar=100 Simulation  474
# 2-Arm, PTS, Npar=100 Simulation  475
# 2-Arm, PTS, Npar=100 Simulation  476
# 2-Arm, PTS, Npar=100 Simulation  477
# 2-Arm, PTS, Npar=100 Simulation  478
# 2-Arm, PTS, Npar=100 Simulation  479
# 2-Arm, PTS, Npar=100 Simulation  480
# 2-Arm, PTS, Npar=100 Simulation  481
# 2-Arm, PTS, Npar=100 Simulation  482
# 2-Arm, PTS, Npar=100 Simulation  483
# 2-Arm, PTS, Npar=100 Simulation  484
# 2-Arm, PTS, Npar=100 Simulation  485
# 2-Arm, PTS, Npar=100 Simulation  486
# 2-Arm, PTS, Npar=100 Simulation  487
# 2-Arm, PTS, Npar=100 Simulation  488
# 2-Arm, PTS, Npar=100 Simulation  489
# 2-Arm, PTS, Npar=100 Simulation  490
# 2-Arm, PTS, Npar=100 Simulation  491
# 2-Arm, PTS, Npar=100 Simulation  492
# 2-Arm, PTS, Npar=100 Simulation  493
# 2-Arm, PTS, Npar=100 Simulation  494
# 2-Arm, PTS, Npar=100 Simulation  495
# 2-Arm, PTS, Npar=100 Simulation  496
# 2-Arm, PTS, Npar=100 Simulation  497
# 2-Arm, PTS, Npar=100 Simulation  498
# 2-Arm, PTS, Npar=100 Simulation  499
